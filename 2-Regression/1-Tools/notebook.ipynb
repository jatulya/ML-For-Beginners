# %%
import sys
print(sys.executable)
# Out:
# c:\Users\RJATU\OneDrive\Documents\programs\python\ML-For-Beginners\.venv\Scripts\python.exe

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape) #op:- 442 rows with 10 columns
print(X[0]) #first row
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
X=X[:,7] #selecting all rows (:) and third column (2)
print("before reshaping: ", X[0])
print(X.shape)
X=X.reshape((-1,1)) #reshaping the array to have one column
print("before reshaping: ", X[0])
print(X.shape)
# Out:
# before reshaping:  -0.002592261998183278
# (442,)
# before reshaping:  [-0.00259226]
# (442, 1)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_[0])
print(model.intercept_)
# Out:
# 647.5309871761455
# 154.44851619495594

# %%
y_pred = model.predict(X_test)
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()
